# %% [markdown]
# # 项目要点
#
# ## agent能力
#
# ### RAG部分
#
# 1. 文本切分：递归字符分块RecursiveCharacterTextSplitter
# 2. 向量嵌入：
# 3. 检索优化：混合检索（Hybrid Search）：BM25+embedding，使用 RRF 融合密集向量和稀疏向量的检索结果

# %% [markdown]
# # TODO
#
# ## agent能力
#
# ### RAG部分
# 1. 文本切分 改为语义分块（Semantic Chunking）
# 3. 向量嵌入：加入多模态embedding
# 4. 检索优化：子问题检索、利用元数据、提供参考文件来源
# 4. 生成优化：多文档场景下的refine
# 5. 提问改写
# 6. RAG评估
#
# ### 其他部分
# 2. excel查询
#
#
# ## 后端服务
#
# 1. 用户注册登录、密码加密、权限管理、ORM数据库-sqlalchemy
# 2. 聊天记录写入数据库，加入redis
